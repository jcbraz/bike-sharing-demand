# %%
import pandas as pd
import seaborn as sns
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from xgboost import XGBClassifier, XGBRegressor

# %%
df = pd.read_csv("./outputs/train_processed.csv")
df.sample(20)
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 682        1        0           0        1  12.30  13.635        28
# 7587       2        0           1        1  25.42  31.060        38
# 2947       3        0           1        1  28.70  32.575        51
# 6335       1        0           1        1  17.22  21.210        77
# 6907       2        0           0        1  14.76  18.180        66
# 3589       3        0           0        1  30.34  34.850        70
# 2882       3        0           1        1  30.34  34.090        58
# 4235       4        0           1        3  22.14  25.760        94
# 5048       4        0           1        2  12.30  15.150        70
# 8698       3        0           1        1  31.98  34.850        40
# 2932       3        0           1        1  24.60  29.545        73
# 8275       3        0           0        3  28.70  33.335        79
# 900        1        0           1        2   7.38   9.090        64
# 4612       4        0           1        1  15.58  19.695        87
# 9669       4        0           1        2  21.32  25.000        45
# 563        1        0           1        1   8.20  12.880        80
# 3029       3        0           1        2  29.52  34.850        74
# 8728       3        0           1        1  31.16  36.365        66
# 5473       1        0           0        1  15.58  19.695        43
# 9409       4        0           1        1  29.52  32.575        42
#
#       windspeed  casual  registered  count  month  day  hour
# 682     22.0028      30          84    114      2   12    11
# 7587    27.9993      91         554    645      6    4    19
# 2947    15.0013      92         251    343      7   15    20
# 6335    15.0013       1          28     29      3    8     5
# 6907     7.0015       2           5      7      4   14     5
# 3589    19.9995     104         125    229      9    4    20
# 2882    12.9980       0           4      4      7   13     3
# 4235     6.0032      13          41     54     10   12    23
# 5048    11.0014      11         115    126     12    9    10
# 8698    11.0014      79         175    254      8   13    13
# 2932     8.9981       7          16     23      7   15     5
# 8275    11.0014     199         259    458      7   14    17
# 900     12.9980       0           2      2      3    4     2
# 4612     0.0000       5          61     66     11    9    23
# 9669    22.0028      69         256    325     10   16    12
# 563      0.0000       0           3      3      2    7     2
# 3029     7.0015       8         126    134      7   19     6
# 8728    12.9980      94         533    627      8   14    19
# 5473    15.0013      78         273    351      1    8    12
# 9409    11.0014     161         307    468     10    5    12

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
regressors = {
    "lasso": {
        "model": Lasso(),
        "params": {
            "alpha": [0.1, 0.5, 1.0]
        }
    },
    "ridge": {
        "model": Ridge(),
        "params": {
            "alpha": [0.1, 0.5, 1.0]
        }
    },
    "elasticnet": {
        "model": ElasticNet(),
        "params": {
            "alpha": [0.1, 0.5, 1.0]
        }
    },
    "xgb": {
        "model": XGBRegressor(),
        "params": {
            "n_estimators": [100, 200, 300],
            "learning_rate": [0.1, 0.01, 0.001]
        }
    },
    "random_forest": {
        "model": RandomForestRegressor(),
        "params": {
            "n_estimators": [100, 200, 300],
            "max_depth": [5, 10, 15]
        }
    }
}

# %%
def run_regressors(
    regressors: dict[str, dict], X_train: pd.DataFrame, y_train: pd.Series
) -> Pipeline:

    for regressor, regressor_content in regressors.items():
        if regressor == "xgboost":
            clf = GridSearchCV(
                estimator=regressor_content["model"],
                param_grid=regressor_content["params"],
                cv=2,
                verbose=2,
            )
            le = LabelEncoder()
            le_y_train = le.fit_transform(y_train)
            clf.fit(X_train, le_y_train)
        else:
            clf = GridSearchCV(
                estimator=regressor_content["model"],
                param_grid=regressor_content["params"],
                cv=2,
                verbose=2,
            )
            clf.fit(X_train, y_train)

    return clf.best_estimator_

# %%
clf = run_regressors(regressors=regressors, X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /Users/jcbraz/University/BBS/bike-sharing-demand/.venv/lib/python3.12/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [CV] END ..........svc__C=1, svc__gamma=0.1, svc__kernel=rbf; total time=  11.0s
# [CV] END ..........svc__C=1, svc__gamma=0.1, svc__kernel=rbf; total time=  10.4s
# [CV] END ..........svc__C=1, svc__gamma=0.1, svc__kernel=rbf; total time=  10.4s
# [CV] END ..........svc__C=1, svc__gamma=0.1, svc__kernel=rbf; total time=  10.3s
# [CV] END ..........svc__C=1, svc__gamma=0.1, svc__kernel=rbf; total time=  10.5s
# [CV] END .......svc__C=1, svc__gamma=0.1, svc__kernel=linear; total time=  13.8s
# [CV] END .......svc__C=1, svc__gamma=0.1, svc__kernel=linear; total time=  13.6s
# [CV] END .......svc__C=1, svc__gamma=0.1, svc__kernel=linear; total time=  13.5s
# [CV] END .......svc__C=1, svc__gamma=0.1, svc__kernel=linear; total time=  13.8s
# [CV] END .......svc__C=1, svc__gamma=0.1, svc__kernel=linear; total time=  13.9s
# [CV] END .........svc__C=1, svc__gamma=0.01, svc__kernel=rbf; total time=   9.4s
# [CV] END .........svc__C=1, svc__gamma=0.01, svc__kernel=rbf; total time=   9.3s
# [CV] END .........svc__C=1, svc__gamma=0.01, svc__kernel=rbf; total time=   9.3s
# [CV] END .........svc__C=1, svc__gamma=0.01, svc__kernel=rbf; total time=   9.3s
# [CV] END .........svc__C=1, svc__gamma=0.01, svc__kernel=rbf; total time=   9.4s
# [CV] END ......svc__C=1, svc__gamma=0.01, svc__kernel=linear; total time=  13.9s
# [CV] END ......svc__C=1, svc__gamma=0.01, svc__kernel=linear; total time=  13.5s
# [CV] END ......svc__C=1, svc__gamma=0.01, svc__kernel=linear; total time=  13.5s
# [CV] END ......svc__C=1, svc__gamma=0.01, svc__kernel=linear; total time=  13.6s
# [CV] END ......svc__C=1, svc__gamma=0.01, svc__kernel=linear; total time=  14.1s
# [CV] END ........svc__C=1, svc__gamma=0.001, svc__kernel=rbf; total time=   9.5s
# [CV] END ........svc__C=1, svc__gamma=0.001, svc__kernel=rbf; total time=   9.8s
# [CV] END ........svc__C=1, svc__gamma=0.001, svc__kernel=rbf; total time=   9.0s
# [CV] END ........svc__C=1, svc__gamma=0.001, svc__kernel=rbf; total time=   9.3s
# [CV] END ........svc__C=1, svc__gamma=0.001, svc__kernel=rbf; total time=   9.3s
# [CV] END .....svc__C=1, svc__gamma=0.001, svc__kernel=linear; total time=  13.7s
# [CV] END .....svc__C=1, svc__gamma=0.001, svc__kernel=linear; total time=  13.6s
# [CV] END .....svc__C=1, svc__gamma=0.001, svc__kernel=linear; total time=  13.5s
# [CV] END .....svc__C=1, svc__gamma=0.001, svc__kernel=linear; total time=  13.6s
# [CV] END .....svc__C=1, svc__gamma=0.001, svc__kernel=linear; total time=  13.8s
# [CV] END .........svc__C=10, svc__gamma=0.1, svc__kernel=rbf; total time=  11.2s
# [CV] END .........svc__C=10, svc__gamma=0.1, svc__kernel=rbf; total time=  11.4s
# [CV] END .........svc__C=10, svc__gamma=0.1, svc__kernel=rbf; total time=  11.4s
# [CV] END .........svc__C=10, svc__gamma=0.1, svc__kernel=rbf; total time=  11.3s
# [CV] END .........svc__C=10, svc__gamma=0.1, svc__kernel=rbf; total time=  11.1s
# [CV] END ......svc__C=10, svc__gamma=0.1, svc__kernel=linear; total time=  24.1s
# [CV] END ......svc__C=10, svc__gamma=0.1, svc__kernel=linear; total time=  24.4s
# [CV] END ......svc__C=10, svc__gamma=0.1, svc__kernel=linear; total time=  23.8s
# [CV] END ......svc__C=10, svc__gamma=0.1, svc__kernel=linear; total time=  23.9s
# [CV] END ......svc__C=10, svc__gamma=0.1, svc__kernel=linear; total time=  24.4s
# [CV] END ........svc__C=10, svc__gamma=0.01, svc__kernel=rbf; total time=  10.9s
# [CV] END ........svc__C=10, svc__gamma=0.01, svc__kernel=rbf; total time=  10.5s
# [CV] END ........svc__C=10, svc__gamma=0.01, svc__kernel=rbf; total time=  10.3s
# [CV] END ........svc__C=10, svc__gamma=0.01, svc__kernel=rbf; total time=  10.4s
# [CV] END ........svc__C=10, svc__gamma=0.01, svc__kernel=rbf; total time=  10.4s
# [CV] END .....svc__C=10, svc__gamma=0.01, svc__kernel=linear; total time=  24.1s
# [CV] END .....svc__C=10, svc__gamma=0.01, svc__kernel=linear; total time=  24.2s
# [CV] END .....svc__C=10, svc__gamma=0.01, svc__kernel=linear; total time=  23.6s
# [CV] END .....svc__C=10, svc__gamma=0.01, svc__kernel=linear; total time=  23.9s
# [CV] END .....svc__C=10, svc__gamma=0.01, svc__kernel=linear; total time=  23.9s
# [CV] END .......svc__C=10, svc__gamma=0.001, svc__kernel=rbf; total time=   9.5s
# [CV] END .......svc__C=10, svc__gamma=0.001, svc__kernel=rbf; total time=   9.5s
# [CV] END .......svc__C=10, svc__gamma=0.001, svc__kernel=rbf; total time=   9.4s
# [CV] END .......svc__C=10, svc__gamma=0.001, svc__kernel=rbf; total time=   9.4s
# [CV] END .......svc__C=10, svc__gamma=0.001, svc__kernel=rbf; total time=   9.4s
# [CV] END ....svc__C=10, svc__gamma=0.001, svc__kernel=linear; total time=  24.4s
# [CV] END ....svc__C=10, svc__gamma=0.001, svc__kernel=linear; total time=  24.3s
# [CV] END ....svc__C=10, svc__gamma=0.001, svc__kernel=linear; total time=  23.5s
# [CV] END ....svc__C=10, svc__gamma=0.001, svc__kernel=linear; total time=  23.9s
# [CV] END ....svc__C=10, svc__gamma=0.001, svc__kernel=linear; total time=  24.0s
# [CV] END ........svc__C=100, svc__gamma=0.1, svc__kernel=rbf; total time=  11.4s
# [CV] END ........svc__C=100, svc__gamma=0.1, svc__kernel=rbf; total time=  11.5s
# [CV] END ........svc__C=100, svc__gamma=0.1, svc__kernel=rbf; total time=  11.6s
# [CV] END ........svc__C=100, svc__gamma=0.1, svc__kernel=rbf; total time=  11.4s
# [CV] END ........svc__C=100, svc__gamma=0.1, svc__kernel=rbf; total time=  14.9s
# [CV] END .....svc__C=100, svc__gamma=0.1, svc__kernel=linear; total time=  39.6s
# [CV] END .....svc__C=100, svc__gamma=0.1, svc__kernel=linear; total time=  36.5s
# [CV] END .....svc__C=100, svc__gamma=0.1, svc__kernel=linear; total time=  29.3s
# [CV] END .....svc__C=100, svc__gamma=0.1, svc__kernel=linear; total time=  29.4s
# [CV] END .....svc__C=100, svc__gamma=0.1, svc__kernel=linear; total time=  29.5s
# [CV] END .......svc__C=100, svc__gamma=0.01, svc__kernel=rbf; total time=   9.7s
# [CV] END .......svc__C=100, svc__gamma=0.01, svc__kernel=rbf; total time=   9.3s
# [CV] END .......svc__C=100, svc__gamma=0.01, svc__kernel=rbf; total time=   9.6s
# [CV] END .......svc__C=100, svc__gamma=0.01, svc__kernel=rbf; total time=   9.9s
# [CV] END .......svc__C=100, svc__gamma=0.01, svc__kernel=rbf; total time=   9.5s
# [CV] END ....svc__C=100, svc__gamma=0.01, svc__kernel=linear; total time=  28.6s
# [CV] END ....svc__C=100, svc__gamma=0.01, svc__kernel=linear; total time=  29.1s
# [CV] END ....svc__C=100, svc__gamma=0.01, svc__kernel=linear; total time=  28.0s
# [CV] END ....svc__C=100, svc__gamma=0.01, svc__kernel=linear; total time=  28.1s

# %%
if not os.path.exists("./models"):
    os.makedirs("./models")

joblib.dump(clf.best_estimator_, "./models/classifier.pkl")
